# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhay5755/Machine_learning/blob/master/DSP_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Digital Signal Processing Assignment

# %% [markdown]
#  **Name**- Abhay Kumar
#
#  **Roll** No.-17412

# %%
from google.colab import drive

drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ## **QUESTION_1**

# %%
# %cd /content/gdrive/My Drive/Assignment/Assignment/Images
# Out:
# /content/gdrive/My Drive/Assignment/Assignment/Images

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img_1=cv2.imread('Fig0304(a)(breast_digital_Xray).tif',0)

# %%
plt.imshow(img_1)

# %%
img_2=255-img_1

# %%
plt.imshow(img_2)

# %% [markdown]
# ## **QUESTION 2**

# %%
img_1=cv2.imread('Fig0305(a)(DFT_no_log).tif',0)
img_2=np.uint8(np.log1p(img_1))
c=1
img_3=cv2.threshold(img_2,c,255,cv2.THRESH_BINARY)[1]

# %% [markdown]
# original image

# %%
plt.imshow(img_1)

# %% [markdown]
# final image

# %%
plt.imshow(img_3)

# %% [markdown]
# ## QUE **3**

# %%
img=cv2.imread('Fig0307(a)(intensity_ramp).tif',0)
plt.imshow(img)

# %%
gamma=2.5
img_gamma=np.power(img,gamma)
plt.imshow(img_gamma)

# %% [markdown]
# # QUESTION 4

# %%
image_1=cv2.imread('Fig0308(a)(fractured_spine).tif',0)
plt.imshow(image_1)

# %%
gamma=0.6
img=np.power(image_1,gamma)
plt.imshow(img)

# %%
gamma=0.4
img_4=np.power(image_1,gamma)
plt.imshow(img_4)

# %%
gamma=0.3
img_5=np.power(image_1,gamma)
plt.imshow(img_5)

# %% [markdown]
# ## **QUESTION 5**

# %%
fig_1=cv2.imread('Fig0309(a)(washed_out_aerial_image).tif',0)
plt.imshow(fig_1)

# %%
gamma=3
fig_2=np.power(fig_1,gamma)
plt.imshow(fig_2)

# %%
gamma=4
fig_3=np.power(fig_1,gamma)
plt.imshow(fig_3)

# %%
gamma=5
fig_4=np.power(fig_1,gamma)
plt.imshow(fig_4)

# %% [markdown]
# # **`QUESTION 7`**

# %%
import math

# %%
def show(img):
    plt.imshow(img, cmap='gray', vmin=0., vmax=L-1.)
    plt.show()

# %%
def compare(r, s):
    fig, ax = plt.subplots(1, 2)
    ax[0].set_title('r')
    ax[0].set_axis_off()
    ax[0].imshow(r, cmap="gray", vmin=0., vmax=L-1.)
    ax[1].set_title('s')
    ax[1].set_axis_off()
    ax[1].imshow(s, cmap="gray", vmin=0., vmax=L-1.)
    plt.savefig('que 7.png', dpi=300, bbox_inches='tight')
    plt.show()

# %%
def gray_level_slice(img, grange, new_gray, binary=False):
    r = img
    rmin = grange[0]
    rmax = grange[1]
    if binary:
        s = np.where(np.logical_and(r >= rmin, r <= rmax),
                new_gray, 0).astype(float)
    else:
        s = np.where(np.logical_and(r >= rmin, r <= rmax),
                new_gray, r).astype(float)
    return s

# %%
image = plt.imread(r"Fig0312(a)(kidney).tif")
L = 256
grayRange = (10,40)
graySlice = gray_level_slice(image, grayRange, 200)
graySlice1 = gray_level_slice(image, grayRange, 200, binary=True)
compare(image, graySlice)
compare(image, graySlice1)

# %% [markdown]
# ## **Question 9**

# %%
img = cv2.imread('Fig0320(1)(top_left).tif')
color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv2.calcHist([img],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.show()

# %% [markdown]
# question 9 B

# %%
img_2 = cv2.imread('Fig0320(2)(2nd_from_top).tif')
color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv2.calcHist([img_2],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.show()

# %% [markdown]
# question 9 C

# %%
img_3= cv2.imread('Fig0316(3)(third_from_top).tif')
color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv2.calcHist([img_3],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.show()

# %% [markdown]
# Question 9 D

# %%
img_4= cv2.imread('Fig0316(4)(bottom_left).tif')
color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv2.calcHist([img_4],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.show()

# %% [markdown]
# ## **QUESTION 10**

# %% [markdown]
# 10 A

# %%
img = cv2.imread('Fig0320(1)(top_left).tif',0)
equ = cv2.equalizeHist(img)
res = np.hstack((img,equ)) #stacking images side-by-side
plt.imshow(res)

# %% [markdown]
# 10 B

# %%
img = cv2.imread('Fig0320(2)(2nd_from_top).tif',0)
equ = cv2.equalizeHist(img)
res = np.hstack((img,equ)) #stacking images side-by-side
plt.imshow(res)

# %% [markdown]
# 10 C

# %%
img = cv2.imread('Fig0320(3)(third_from_top).tif',0)
equ = cv2.equalizeHist(img)
res = np.hstack((img,equ)) #stacking images side-by-side
plt.imshow(res)

# %% [markdown]
# 10 D

# %%
img = cv2.imread('Fig0320(4)(bottom_left).tif',0)
equ = cv2.equalizeHist(img)
res = np.hstack((img,equ)) #stacking images side-by-side
plt.imshow(res)

# %% [markdown]
# ## **Question 13**

# %%
from skimage import data
from skimage.util import img_as_ubyte
from skimage import exposure
import skimage.morphology as morp
from skimage.filters import rank

# %%
# Original image
img=cv2.imread(r"Fig0326(a)(embedded_square_noisy_512).tif",0)

# Global equalize
img_global = exposure.equalize_hist(img)

# Local Equalization, disk shape kernel
# Better contrast with disk kernel but could be different
kernel = morp.disk(30)
img_local = rank.equalize(img, selem=kernel)

fig, (ax_img, ax_global, ax_local) = plt.subplots(1, 3)

ax_img.imshow(img, cmap=plt.cm.gray)
ax_img.set_title('Low contrast image')
ax_img.set_axis_off()

ax_global.imshow(img_global, cmap=plt.cm.gray)
ax_global.set_title('Global equalization')
ax_global.set_axis_off()

ax_local.imshow(img_local, cmap=plt.cm.gray)
ax_local.set_title('Local equalization')
ax_local.set_axis_off()

plt.show()

# %% [markdown]
# ## QUESTION **14**

# %%
from skimage import data
from skimage.util import img_as_ubyte
from skimage import exposure
import skimage.morphology as morp
from skimage.filters import rank

# %%
# Original image
img=cv2.imread(r"Fig0327(a)(tungsten_original).tif",0)


# Global equalize
img_global = exposure.equalize_hist(img)

# Local Equalization, disk shape kernel
# Better contrast with disk kernel but could be different
kernel = morp.disk(30)
img_local = rank.equalize(img,selem=kernel)

fig, (ax_img, ax_local) = plt.subplots(1, 2)

ax_img.imshow(img, cmap=plt.cm.gray)
ax_img.set_title('Low contrast image')
ax_img.set_axis_off()



ax_local.imshow(img_local, cmap=plt.cm.gray)
ax_local.set_title('Local equalization')
ax_local.set_axis_off()

plt.show()
